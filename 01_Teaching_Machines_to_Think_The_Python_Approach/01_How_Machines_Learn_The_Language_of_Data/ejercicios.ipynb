# %% [markdown]
# # 📝 Ejercicios: Introducción a Machine Learning
#
# **Módulo 1: Machine Learning with Python**
#
# ---
#
# ## 🎯 Objetivos
#
# Estos ejercicios te ayudarán a consolidar lo aprendido sobre:
# - NumPy y operaciones con arrays
# - Pandas y manipulación de datos
# - Visualización con Matplotlib
# - Primer modelo de Machine Learning
#
# ---
#
# ## 📋 Instrucciones
#
# 1. Lee cuidadosamente cada ejercicio
# 2. Escribe tu código en las celdas proporcionadas
# 3. Ejecuta y verifica tus resultados
# 4. Si te atascas, revisa el notebook de práctica guiada
# 5. **¡No veas las soluciones hasta haberlo intentado!**
#
# ---
#
# ## ⚙️ Configuración Inicial

# %%
# Importar bibliotecas necesarias
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# Configuración de visualización
# %matplotlib inline
plt.style.use('seaborn-v0_8-darkgrid')
plt.rcParams['figure.figsize'] = (10, 6)

# Semilla para reproducibilidad
np.random.seed(42)

print("✅ Bibliotecas importadas correctamente")

# %% [markdown]
# ---
#
# ## Ejercicio 1: Operaciones con NumPy (⭐)
#
# ### Contexto:
# Tienes las ventas mensuales (en miles de dólares) de una tienda durante un año.
#
# ### Tareas:
# 1. Crea un array con las ventas: `[45, 52, 48, 61, 55, 58, 62, 70, 65, 68, 72, 80]`
# 2. Calcula:
#    - Media de ventas
#    - Mediana
#    - Desviación estándar
#    - Ventas mínimas y máximas
# 3. Calcula el incremento porcentual del primer al último mes
# 4. Crea un nuevo array con las ventas normalizadas (restar la media y dividir por la desv. estándar)

# %%
# Tu código aquí

# %% [markdown]
# ---
#
# ## Ejercicio 2: Análisis de Datos con Pandas (⭐⭐)
#
# ### Contexto:
# Tienes datos de estudiantes con sus calificaciones en diferentes materias.
#
# ### Datos:

# %%
# Ejecuta esta celda para crear el DataFrame
datos_estudiantes = {
    'Nombre': ['Ana', 'Luis', 'Carlos', 'María', 'Pedro', 'Laura', 'José', 'Carmen', 'Miguel', 'Sara'],
    'Matemáticas': [85, 78, 92, 88, 76, 95, 82, 90, 84, 91],
    'Física': [82, 75, 88, 85, 79, 92, 80, 87, 83, 89],
    'Química': [88, 80, 90, 92, 82, 94, 85, 91, 86, 93],
    'Horas_Estudio': [15, 10, 20, 18, 12, 22, 14, 19, 16, 21]
}

df_estudiantes = pd.DataFrame(datos_estudiantes)
print(df_estudiantes)

# %% [markdown]
# ### Tareas:
#
# 1. Calcula el promedio de cada estudiante (promedio de las 3 materias) y agrégalo como una nueva columna llamada `'Promedio'`
# 2. Encuentra el estudiante con el mejor promedio
# 3. Filtra los estudiantes con promedio mayor a 85
# 4. Calcula la correlación entre `Horas_Estudio` y `Promedio`
# 5. Ordena el DataFrame por `Promedio` de mayor a menor

# %%
# Tu código aquí - Tarea 1: Calcular promedio

# %%
# Tu código aquí - Tarea 2: Mejor estudiante

# %%
# Tu código aquí - Tarea 3: Filtrar estudiantes

# %%
# Tu código aquí - Tarea 4: Correlación

# %%
# Tu código aquí - Tarea 5: Ordenar

# %% [markdown]
# ---
#
# ## Ejercicio 3: Visualización con Matplotlib (⭐⭐)
#
# ### Contexto:
# Usando el DataFrame de estudiantes del ejercicio anterior.
#
# ### Tareas:
#
# 1. Crea un **gráfico de barras** mostrando el promedio de cada estudiante
# 2. Crea un **scatter plot** de `Horas_Estudio` vs `Promedio` y agrega una línea de tendencia
# 3. Crea un **histograma** de los promedios con 5 bins
# 4. Crea una figura con 2x2 subplots mostrando:
#    - Gráfico de barras del promedio
#    - Scatter de Horas_Estudio vs Promedio
#    - Histograma de promedios
#    - Gráfico de línea mostrando las calificaciones de Matemáticas de todos los estudiantes

# %%
# Tu código aquí - Tarea 1: Gráfico de barras

# %%
# Tu código aquí - Tarea 2: Scatter plot con tendencia
# Pista: usa np.polyfit() y np.poly1d() para la línea de tendencia

# %%
# Tu código aquí - Tarea 3: Histograma

# %%
# Tu código aquí - Tarea 4: Subplots 2x2

# %% [markdown]
# ---
#
# ## Ejercicio 4: Modelo de Machine Learning (⭐⭐⭐)
#
# ### Contexto:
# Vamos a crear un modelo que prediga las ventas de un producto basándose en el gasto en publicidad.
#
# ### Datos:

# %%
# Ejecuta esta celda para generar los datos
np.random.seed(42)

# Gasto en publicidad (miles de dólares)
gasto_publicidad = np.random.uniform(10, 100, 100)

# Ventas = 50 + 3 * publicidad + ruido
ventas = 50 + 3 * gasto_publicidad + np.random.normal(0, 20, 100)

# Crear DataFrame
df_marketing = pd.DataFrame({
    'Gasto_Publicidad': gasto_publicidad,
    'Ventas': ventas
})

print("Dataset de Marketing:")
print(df_marketing.head())
print(f"\nTotal de registros: {len(df_marketing)}")

# %% [markdown]
# ### Tareas:
#
# 1. **Exploración**:
#    - Calcula estadísticas descriptivas
#    - Crea un scatter plot de Gasto_Publicidad vs Ventas
#    - Calcula la correlación entre ambas variables
#
# 2. **Preparación de datos**:
#    - Separa features (X) y target (y)
#    - Divide en train (80%) y test (20%)
#
# 3. **Entrenamiento**:
#    - Crea un modelo de Regresión Lineal
#    - Entrénalo con los datos de entrenamiento
#    - Muestra el coeficiente y el intercepto
#
# 4. **Evaluación**:
#    - Haz predicciones en el conjunto de prueba
#    - Calcula RMSE y R²
#    - Crea un gráfico mostrando:
#      * Los puntos reales (scatter)
#      * La línea de regresión
#
# 5. **Predicción**:
#    - ¿Cuántas ventas esperarías con un gasto de $50,000 en publicidad?

# %%
# Tu código aquí - Tarea 1: Exploración

# %%
# Tu código aquí - Tarea 2: Preparación

# %%
# Tu código aquí - Tarea 3: Entrenamiento

# %%
# Tu código aquí - Tarea 4: Evaluación

# %%
# Tu código aquí - Tarea 5: Predicción

# %% [markdown]
# ---
#
# ## Ejercicio 5: Proyecto Mini - Análisis de Temperatura (⭐⭐⭐)
#
# ### Contexto:
# Tienes datos de temperatura de una ciudad durante varios días y quieres analizar patrones.
#
# ### Datos:

# %%
# Ejecuta esta celda para generar los datos
np.random.seed(42)

# 90 días de datos
dias = np.arange(1, 91)

# Temperatura con tendencia estacional (simulando primavera)
temperatura_base = 15 + 0.2 * dias  # Incremento gradual
variacion_diaria = 5 * np.sin(dias * 2 * np.pi / 7)  # Variación semanal
ruido = np.random.normal(0, 2, 90)
temperatura = temperatura_base + variacion_diaria + ruido

df_temperatura = pd.DataFrame({
    'Dia': dias,
    'Temperatura_C': temperatura
})

print("Dataset de Temperatura:")
print(df_temperatura.head(10))

# %% [markdown]
# ### Tareas:
#
# **Parte 1: Análisis Exploratorio**
# 1. Calcula:
#    - Temperatura media, mínima y máxima
#    - Desviación estándar
# 2. Crea un gráfico de línea mostrando la temperatura a lo largo del tiempo
# 3. Agrega una línea horizontal para la temperatura media
#
# **Parte 2: Análisis Estadístico**
# 1. Crea una columna `'Semana'` agrupando cada 7 días
# 2. Calcula la temperatura promedio por semana
# 3. Crea un gráfico de barras con el promedio semanal
#
# **Parte 3: Predicción**
# 1. Entrena un modelo de regresión lineal para predecir temperatura basándose en el día
# 2. Evalúa el modelo (RMSE y R²)
# 3. Predice la temperatura para los días 91, 92, 93, 94, 95
# 4. Crea un gráfico mostrando:
#    - Datos históricos (puntos azules)
#    - Predicciones (puntos rojos)
#    - Línea de tendencia
#
# **Parte 4: Insights**
# 1. ¿La temperatura está aumentando o disminuyendo?
# 2. ¿Qué tan confiable es el modelo para predicciones futuras?
# 3. ¿Qué limitaciones tiene este modelo?

# %%
# Parte 1: Análisis Exploratorio

# %%
# Parte 2: Análisis Estadístico

# %%
# Parte 3: Predicción

# %% [markdown]
# **Parte 4: Responde aquí tus insights:**
#
# 1. Tendencia de temperatura:
#    - [Tu respuesta aquí]
#
# 2. Confiabilidad del modelo:
#    - [Tu respuesta aquí]
#
# 3. Limitaciones:
#    - [Tu respuesta aquí]

# %% [markdown]
# ---
#
# ## 🎯 Autoevaluación
#
# Antes de ver las soluciones, verifica:
#
# ### Ejercicio 1: NumPy
# - [ ] Calculé correctamente todas las estadísticas
# - [ ] Entiendo qué es la normalización
# - [ ] Puedo explicar el incremento porcentual
#
# ### Ejercicio 2: Pandas
# - [ ] Creé la columna de promedio correctamente
# - [ ] Puedo filtrar datos con condiciones
# - [ ] Entiendo qué significa la correlación
#
# ### Ejercicio 3: Visualización
# - [ ] Mis gráficos tienen títulos y etiquetas
# - [ ] Puedo crear diferentes tipos de gráficos
# - [ ] Entiendo cuándo usar cada tipo
#
# ### Ejercicio 4: ML Modelo Simple
# - [ ] Dividí correctamente train/test
# - [ ] Entrené y evalué el modelo
# - [ ] Puedo interpretar RMSE y R²
#
# ### Ejercicio 5: Proyecto
# - [ ] Completé todas las partes
# - [ ] Mis gráficos son informativos
# - [ ] Puedo explicar las limitaciones
#
# ---
#
# ## 🚀 Próximos Pasos
#
# 1. **Si completaste todo**: ¡Excelente! Revisa las soluciones para ver enfoques alternativos
# 2. **Si te atascaste**: Está bien, revisa el material teórico y la práctica guiada
# 3. **Si quieres más**: Intenta modificar los ejercicios con tus propios datos
#
# ---
#
# ## 💡 Tips Finales
#
# - 📊 La visualización es clave: siempre grafica tus datos
# - 🔍 Explora antes de modelar: entiende tus datos primero
# - 🧪 Experimenta: cambia parámetros y observa
# - 📖 Lee errores con calma: Python te dice qué está mal
# - 💪 La práctica hace al maestro: ¡sigue practicando!
#
# ---
#
# **¡Mucha suerte con los ejercicios! 🎓**
